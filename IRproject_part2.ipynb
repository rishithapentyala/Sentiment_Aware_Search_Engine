# %%
# Install fuzzywuzzy with optional speedup
# !pip install fuzzywuzzy[speedup]
# Out:
# Collecting fuzzywuzzy[speedup]
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl.metadata (4.9 kB)
# Collecting python-levenshtein>=0.12 (from fuzzywuzzy[speedup])
#   Downloading python_levenshtein-0.27.3-py3-none-any.whl.metadata (3.9 kB)
# Collecting Levenshtein==0.27.3 (from python-levenshtein>=0.12->fuzzywuzzy[speedup])
#   Downloading levenshtein-0.27.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (3.7 kB)
# Collecting rapidfuzz<4.0.0,>=3.9.0 (from Levenshtein==0.27.3->python-levenshtein>=0.12->fuzzywuzzy[speedup])
#   Downloading rapidfuzz-3.14.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (12 kB)
# Downloading python_levenshtein-0.27.3-py3-none-any.whl (9.5 kB)
# Downloading levenshtein-0.27.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (153 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.3/153.3 kB 6.1 MB/s eta 0:00:00
# Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Downloading rapidfuzz-3.14.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 75.7 MB/s eta 0:00:00
# Installing collected packages: fuzzywuzzy, rapidfuzz, Levenshtein, python-levenshtein
# Successfully installed Levenshtein-0.27.3 fuzzywuzzy-0.18.0 python-levenshtein-0.27.3 rapidfuzz-3.14.3

# %%
# Imports
import pandas as pd
import re
from fuzzywuzzy import process, fuzz

# Load your precomputed CSV with Flair, VADER, TextBlob sentiments
df = pd.read_csv('reviews_with_flair.csv')

# Get all unique product names
unique_products = df['product_name'].unique()

# %%
import pandas as pd

# Assuming your DataFrame is already loaded as df
unique_products = df['product_name'].dropna().unique()

# To just see the list
for i, product in enumerate(unique_products, 1):
    print(f"{i}. {product}")

# Or simply
print(unique_products)
# Out:
# 1. Candes 12 L Room/Personal Air Cooler??????(White, Black, Elegant High Speed-Honey Comb Cooling Pad & Ice Chamber, Blower)
# 2. Candes 60 L Room/Personal Air Cooler??????(White, Black, CRETA)
# 3. MAHARAJA WHITELINE 65 L Desert Air Cooler??????(White, Grey, Rambo Grey / AC-303)
# 4. Crompton 75 L Desert Air Cooler??????(White, Teal, ACGC-DAC751)
# 5. boAt Rockerz 510 Super Extra Bass Bluetooth Headset??????(Molten Orange, On the Ear)
# 6. Aroma NB119 Titanium - 48 Hours Playtime Bluetooth Neckband Bluetooth Headset??????(Green, In the Ear)
# 7. OnePlus Bullets Wireless Z2 with Fast Charge, 30 Hrs Battery Life, Earphones with mic Bluetooth Headset??????(Magico Black, In the Ear)
# 8. OnePlus Bullets Wireless Z2 Bluetooth Headset??????(Acoustic Red, In the Ear)
# 9. Mivi Roam2 5 W Bluetooth Speaker??????(Black, Mono Channel)
# 10. etmax NANO BLACK 30 W Bluetooth Home Theatre??????(Black, Stereo Channel)
# 11. Mivi Fort S16 Soundbar with 2 full range drivers, Made in India 16 W Bluetooth Soundbar??????(Black, 2.0 Channel)
# 12. I Kall IK22 40 W Bluetooth Home Theatre??????(Black, 2.1 Channel)
# 13. Sulfur Best Buy Ultra DJ Sound Blast Portable Best Bluetoothwith Super deep Bass Wireless Rechargeable dj Sound Bluetooth| Extra Baas Stereo sound quality |Led Colour Changing Lights | mini Home theatre| Speaker Support TF/USB/Pen Drive/AUX Slot 10 W Bluetooth Car Speaker??????(Black, Stereo Channel)
# 64. BLUECHIP BL43SmartTV TV Voltage Stabilizer for LED TV/Smart TV Up to 43 Inches , Set Top Box??????(Royal Blue)
# 65. BLUECHIP 100% Copper BL72SmartTV3.2Amp TV Voltage Stabilizer for LED TV/Smart TV Up to 72 + Inches + Set Top Box + home theater , With 3 Years Warranty ( 100% Copper )??????(Black, Gold)
# 66. Value Adds Wall Mount Set Top Box Iron Wall Shelf (Number of Shelves - 1, Black) Steel Wall Shelf??????(Number of Shelves - 1, Black)
# 67. D&V ENGINEERING 2 Compartments Iron Remote control holder /stand /organizer for TV AC DTH STB Remotes with attractive DANCING lady??????(Black, Green, RED/PINK)
# 68. D&V ENGINEERING 2 Compartments Iron Remote control holder /stand /organizer for TV AC DTH STB Remotes with attractive Dancing Lady??????(Black, Green, Pink)
# 69. Airtel Regular Digital TV SD/HD DTH Compatible Remote UNIVERSAL Remote Controller??????(Black)
# 70. 7SEVEN Airtel DTH Remote Airtel Xstream Remote Compatible with SD and HD Recording Compatible for original Set top or Setup Box Digital tv Remote Control AIRTEL Set Top Box, AIRTEL Xstream - Android TV Set Top Box Remote Controller??????(Black)
# 71. D&V ENGINEERING 2 Compartments Iron Remote control holder /stand /organizer for TV AC DTH STB Remotes for living room showpiece??????(Black, Green, Pink)
# 72. D&V ENGINEERING Sturdy Set top Box Stand,DVD,DTH,Telephone, WiFi Modems Stand for Home Steel Wall Shelf (Wide Shelf) Iron Wall Shelf??????(Number of Shelves - 1, Black)
# 73. CHARDI KALA Set Top Box / DTH Stand - Wall Mount Stand / Wifi Router Stand, Color : Black (Ideal for All Type of Set Top Box) Cast Iron Wall Shelf (Number of Shelves - 1, Black) Cast Iron Wall Shelf??????(Number of Shelves - 1, Black)
# 74. Tata Sky Tatasky Old model DTH Compatible Setup box Remote- Black Tata Sky Remote Controller??????(Black)
# 75. Airtel Regular Digital TV DTH Remote Compatible with SD and HD Recording (Black) Airtel Remote Controller??????(Black)
# 76. Airtel Dth Settop Box Airtel TV, Airtel set up box, Airtel HD TV Remote Controller??????(Black)
# 77. Nextron NX-AE100 Voltage Stabilizer for Smart LED TV for 32/43/55 inchs+Set Top Box +home theater??????(Black)
# 78. Airtel Airtel Universal Setup box Remote Digital Setup box Universal Remote Airtel Remote Controller??????(Black)
# 79. SQUARO ONLINE STORE Unbreakable Setup Box stand/WiFi Router/DTH Telephone/Mobile Shelf/Holder Acrylic Wall Shelf??????(Number of Shelves - 1, White, Black)
# 80. Tata Sky (Works with all TV) Tatasky set top box, Tatasky SD set top box, Tatasky HD set top box, Tatasky DTH Setup box Remote Controller??????(Black)
# 81. SQUARO ONLINE STORE Unbreakable Setup Box stand/WiFi Router/DTH Telephone/Mobile Shelf/Holder Acrylic Wall Shelf??????(Number of Shelves - 1, Black)
# 82. Flipkart SmartBuy CFXB18 Electric Rice Cooker??????(1.8 L, White, Blue)
# 83. Flipkart SmartBuy CFXB15 Electric Rice Cooker??????(1.5 L, White)
# 84. Prestige PRWO 1.8-2 Electric Rice Cooker with Steaming Feature??????(1.8 L, White)
#  'boAt Rockerz 510 Super Extra Bass Bluetooth Headset??????(Molten Orange, On the Ear)'
#  'Aroma NB119 Titanium - 48 Hours Playtime Bluetooth Neckband Bluetooth Headset??????(Green, In the Ear)'
#  'OnePlus Bullets Wireless Z2 with Fast Charge, 30 Hrs Battery Life, Earphones with mic Bluetooth Headset??????(Magico Black, In the Ear)'
#  'OnePlus Bullets Wireless Z2 Bluetooth Headset??????(Acoustic Red, In the Ear)'
#  'Mivi Roam2 5 W Bluetooth Speaker??????(Black, Mono Channel)'
#  'etmax NANO BLACK 30 W Bluetooth Home Theatre??????(Black, Stereo Channel)'
#  'Mivi Fort S16 Soundbar with 2 full range drivers, Made in India 16 W Bluetooth Soundbar??????(Black, 2.0 Channel)'
#  'I Kall IK22 40 W Bluetooth Home Theatre??????(Black, 2.1 Channel)'
#  'Sulfur Best Buy Ultra DJ Sound Blast Portable Best Bluetoothwith Super deep Bass Wireless Rechargeable dj Sound Bluetooth| Extra Baas Stereo sound quality |Led Colour Changing Lights | mini Home theatre| Speaker Support TF/USB/Pen Drive/AUX Slot 10 W Bluetooth Car Speaker??????(Black, Stereo Channel)'
#  'F FERONS Wireless rechargeable portable Premium bass Multimedia FFRTG-113 9 W Bluetooth Speaker??????(Black, Stereo Channel)'
#  'ZEBRONICS Zeb-Vita Plus 16 W Bluetooth Laptop/Desktop Speaker??????(Black, Stereo Channel)'
#  'Canon EOS 3000D DSLR Camera 1 Camera Body, 18 - 55 mm Lens????????(Black)'
#  'Hindware Nevio Plus 60  Auto Clean Wall Mounted Chimney??????(Black 1400 CMH)'
#  'Faber Hood Mercury Pro HC SC FL BK 60 Auto Clean Wall Mounted Chimney??????(Black 1200 CMH)'
#  'Hindware Ripple 90 Auto Clean Wall Mounted Chimney??????(Black 1350 CMH)'
#  'Whirlpool CLASSIC CF 60 BK HOOD 60 cm 750 m??/hr Wall Mounted Chimney??????(Black 750 CMH)'
#  'Eurodomo Hood Indigo PRO HC SC FL BK 60 Auto Clean Wall Mounted Chimney??????(Black 1200 CMH)'
#  'Glen ISPA 90 BL Auto Clean Wall Mounted Chimney??????(Black 1050 CMH)'
#  'Hindware Ripple 90 Auto Clean Wall Mounted Chimney??????(Inox 1350 CMH)'
#  'CEAT Hitman Full Size Double Blade Poplar Cricket Bat - Advance Play Poplar Willow Cricket  Bat??????(1.2 kg)'
#  'HF MRF GRAND EDITON VK-18 ( Ideal For 15-21 Years) Hard Plastic bat for tennis ball PVC/Plastic Cricket  Bat??????(800-900 g)'
#  'SportSoul Cotton Gym & Athletic Abdomen Support??????(Blue)'
#  'MRF (SIZE-6) TANNIS WOODEN KASHMERI POPULER WILLOW Poplar Willow Cricket  Bat??????(0.3 kg)'
#  'VICTORY Medium Weight ( Pack of 1 ) Rubber Cricket Tennis Ball Cricket Rubber Ball??????(Pack of 1)'
#  'ArrowMax Professional Anti-slip Fitness (Black , pack of 2 ) Easy comfort Wrist Support??????(Black)'
#  'VICTORY Cricket Wind Ball (Pack of 1) - Made in India Smooth Cricket Cricket Synthetic Ball??????(Pack of 1)'
#  'Siemens SN26L201IN/SN256W01GI Free Standing 12 Place Settings Dishwasher'
#  'BLUECHIP BL55SmartTV2.1Amp TV Voltage Stabilizer for LED TV/Smart TV Up to 55 Inches + Set Top Box + home theater??????(Sea-Green)'
#  'DALUCI Set Top Box Stand / WIFI Router Stand / Wall Mount Stand / Wifi Holder MDF (Medium Density Fiber) Wall Shelf??????(Number of Shelves - 2, Black)'
#  'BLUECHIP BL60SmartTV3.1Amp TV Voltage Stabilizer for LED TV/Smart TV Up to 60+ Inches + Set Top Box + home theater , With 3 Years Warranty??????(Gold)'
#  'Supreme Bazaar Abs Setup Box Holder Unbreakable Crystal Clear Premium Quality Set of Box Stand/Dth Stand Plastic Wall Shelf??????(Number of Shelves - 1, Clear)'
#  'Tata Sky Tatasky 03 Dth Univeral SD / HD Set Up Box Remote Controller with Batteries (Black) Tatasky Remote Controller??????(Black)'
#  'BLUECHIP BL43SmartTV TV Voltage Stabilizer for LED TV/Smart TV Up to 43 Inches , Set Top Box??????(Royal Blue)'
#  'BLUECHIP 100% Copper BL72SmartTV3.2Amp TV Voltage Stabilizer for LED TV/Smart TV Up to 72 + Inches + Set Top Box + home theater , With 3 Years Warranty ( 100% Copper )??????(Black, Gold)'
#  'Value Adds Wall Mount Set Top Box Iron Wall Shelf (Number of Shelves - 1, Black) Steel Wall Shelf??????(Number of Shelves - 1, Black)'
#  'D&V ENGINEERING 2 Compartments Iron Remote control holder /stand /organizer for TV AC DTH STB Remotes with attractive DANCING lady??????(Black, Green, RED/PINK)'
#  'D&V ENGINEERING 2 Compartments Iron Remote control holder /stand /organizer for TV AC DTH STB Remotes with attractive Dancing Lady??????(Black, Green, Pink)'
#  'Airtel Regular Digital TV SD/HD DTH Compatible Remote UNIVERSAL Remote Controller??????(Black)'
#  '7SEVEN Airtel DTH Remote Airtel Xstream Remote Compatible with SD and HD Recording Compatible for original Set top or Setup Box Digital tv Remote Control AIRTEL Set Top Box, AIRTEL Xstream - Android TV Set Top Box Remote Controller??????(Black)'
#  'D&V ENGINEERING 2 Compartments Iron Remote control holder /stand /organizer for TV AC DTH STB Remotes for living room showpiece??????(Black, Green, Pink)'
#  'D&V ENGINEERING Sturdy Set top Box Stand,DVD,DTH,Telephone, WiFi Modems Stand for Home Steel Wall Shelf (Wide Shelf) Iron Wall Shelf??????(Number of Shelves - 1, Black)'
#  'CHARDI KALA Set Top Box / DTH Stand - Wall Mount Stand / Wifi Router Stand, Color : Black (Ideal for All Type of Set Top Box) Cast Iron Wall Shelf (Number of Shelves - 1, Black) Cast Iron Wall Shelf??????(Number of Shelves - 1, Black)'
#  'Tata Sky Tatasky Old model DTH Compatible Setup box Remote- Black Tata Sky Remote Controller??????(Black)'
#  'Airtel Regular Digital TV DTH Remote Compatible with SD and HD Recording (Black) Airtel Remote Controller??????(Black)'
#  'Airtel Dth Settop Box Airtel TV, Airtel set up box, Airtel HD TV Remote Controller??????(Black)'
#  'Nextron NX-AE100 Voltage Stabilizer for Smart LED TV for 32/43/55 inchs+Set Top Box +home theater??????(Black)'
#  'Airtel Airtel Universal Setup box Remote Digital Setup box Universal Remote Airtel Remote Controller??????(Black)'
#  'SQUARO ONLINE STORE Unbreakable Setup Box stand/WiFi Router/DTH Telephone/Mobile Shelf/Holder Acrylic Wall Shelf??????(Number of Shelves - 1, White, Black)'
#  'Tata Sky (Works with all TV) Tatasky set top box, Tatasky SD set top box, Tatasky HD set top box, Tatasky DTH Setup box Remote Controller??????(Black)'
#  'SQUARO ONLINE STORE Unbreakable Setup Box stand/WiFi Router/DTH Telephone/Mobile Shelf/Holder Acrylic Wall Shelf??????(Number of Shelves - 1, Black)'
#  'Flipkart SmartBuy CFXB18 Electric Rice Cooker??????(1.8 L, White, Blue)'
#  'Flipkart SmartBuy CFXB15 Electric Rice Cooker??????(1.5 L, White)'
#  'Prestige PRWO 1.8-2 Electric Rice Cooker with Steaming Feature??????(1.8 L, White)'
#  'WONDERCHEF Nutri Pot Electric Pressure Cooker??????(3 L, Black & Silver)'
#  'Prestige Atlas Delight Electric Rice Cooker??????(1.8 L, Blue)'
#  'Adonai POT1.5LPINK Rice Cooker, Food Steamer, Travel Cooker, Slow Cooker, Electric Pressure Cooker??????(1.5 L, Pink)'
#  'Butterfly Rapid Kettle 1.5 Litre + Eco 750 Ml Water Bottle'
#  'Pigeon Favourite Electric Kettle??????(1.5 L, Silver, Black)'
#  'Seagate One Touch with Password Protection for Windows & Mac with 3 years Data Recovery Services - Portable 1 TB External Hard Disk Drive (HDD)??????????(Space Gray)'
#  'Seagate Expansion for Windows and Mac with 3 years Data Recovery Services ?????? Portable 1 TB External Hard Disk Drive (HDD)??????????(Black)'
#  'Seagate One Touch with Password Protection for Windows & Mac with 3 years Data Recovery Services - Portable 2 TB External Hard Disk Drive (HDD)??????????(Light Blue)'
#  'WD Elements 2 TB Wired External Hard Disk Drive (HDD)??????????(Black)'
#  'WD 1.5 TB Wired External Hard Disk Drive (HDD)??????????(Black)'
#  'LUMINOUS Vento Dlx 150 mm 5 Blade Exhaust Fan??????????(White)'
#  'Atomberg Renesa 1200 mm BLDC Motor with Remote 3 Blade Ceiling Fan??????????(Ivory & Black, Pack of 1)'
#  'BAJAJ Crest Neo 1200 mm 3 Blade Ceiling Fan??????????(Brown, Pack of 1)'
#  'Candes Florence 1200 mm Energy Saving 3 Blade Ceiling Fan??????????(Silver Blue, Pack of 2)'
#  'Crompton Hill Briz Deco 1200 mm 3 Blade Ceiling Fan??????????(Smoked Brown, Pack of 1)'
#  'BAJAJ Crest Neo 1200 mm 3 Blade Ceiling Fan??????????(White, Pack of 1)'
#  'Inalsa fiesta 650 W Food Processor??????????(White)'
#  'USHA FP 3811_ 1000 W Food Processor??????????(Black, Silver)'
#  'PUHBRHY Steel Electric Meat Grinders for Kitchen Food Chopper, Meat, Vegetables, 700 W Food Processor??????????(Multicolor)'
#  'Inalsa Inox 1000 1000 W Food Processor??????????(Silver:Black)'
#  'HAVELLS convenio 500 W Food Processor??????????(Black)'
#  'USHA FP 3810_ 1000 W Food Processor??????????(Black, Silver)'
#  'BAJAJ FX 11 Food Factory 600 W Food Processor??????????(White)'
#  'Inalsa Verve 800W Food Processor with 100% Pure Copper Motor| 2 Multipurpose Jars & 11 Accessories 800 W Food Processor??????????(Black/Rose Gold)'
#  'Inalsa Inox 1000 Plus 1000 W Food Processor??????????(Black/Silver)'
#  'Butterfly Cresta 4 Jars 750 W Food Processor??????????(Turquoise Green)'
#  'Inalsa Easy Prep_ 800 W Food Processor??????????(Black)'
#  'Inalsa Maxie Marvel 800 W Food Processor??????????(White)'
#  'BAJAJ Masterchef 3.0 food processor 600 W Food Processor??????????(White)'
#  'Inalsa Wonder Maxie Plus 700 W Food Processor??????????(White)'
#  'BAJAJ FX7 600 W Food Processor'
#  'KENT Vegetable Cleaner - Counter Top 250 W Food Processor??????????(Silver, Black)'
#  'PHILIPS hl 1660 700 W Food Processor??????????(White)'
#  'Prestige CleanHome Fruit and Vegetable Cleaner (P0Z 1.0 ) 230 Volts Food Processor??????????(White and Blue)'
#  'Butterfly Magic Fruit & Vegetable Cleaner 250 W Food Processor??????????(White)'
#  'Inalsa Maxie Premia 800 W Food Processor??????????(Grey PU Spray Painted)'
#  'WONDERCHEF Nutri-blend FP-Compact 350 W Food Processor??????????(Black)'
#  'BAJAJ Fx11 Food Factory 600 W Food Processor??????????(White)'
#  'BAJAJ 410053 600 W Food Processor??????????(Multicolor)'
#  'Inalsa Fiesta Lx 650 W Food Processor??????????(White)'
#  'MAHARAJA WHITELINE Fortune FP - 102 600 W Food Processor??????????(White & Mystic Blue)'
#  'PHILIPS HR7627/00 650 W Food Processor??????????(White)'
#  'PHILIPS HL1661/00 700 W Food Processor??????????(White)'
#  'Choose The Correct ?? LED Music Bulb with Bluetooth Speaker Music Color changing led Bulb, DJ Lights with Remote Control Music Dimmable for Home, Bedroom, Living Room, Decoration smart bulb with Google, Alexa & Siri Assistant Smart Speaker??????(Multicolor)'
#  'Google Nest Mini (2nd Gen) with Google Assistant with Google Assistant Smart Speaker??????(Charcoal)'
#  'Google Nest Hub (2nd gen), Display with Google Assistant Smart Speaker??????(Charcoal)'
#  'Google Nest Mini (2nd Gen) with Google Assistant Smart Speaker??????(Chalk)'
#  'VARDHMAN Velcro tape industial quality , 2 inches ( 50 m ) width,color black, pack of 5 mts Sew-on Velcro??????(Black)'
#  'Wishpool Cut Resistant Gloves - High Performance Level 5 Protection, Food Grade FREE SIZE Synthetic  Safety Gloves??????(2)'
#  'PRAGATI TRENDS Lab Coat??????(Poly Cotton)'
#  'Joker GBLK-6 Genuine leather safety shoes for men Steel Toe Genuine Leather Safety Shoe??????(Black, SB, SBP, S1, S1P, S2, S2P, S3, S4, S5, SRA, SRB, SRC)'
#  'Glun Water Quality Purity Tester 0-990 PPM Digital TDS Meter'
#  'Divinext 1 week Pill Medicine Tablet Case box Storage 28 Days Pill Box??????(Multicolor)'
#  'BALKRISHNA ENTERPRISE Green Tea Sticks Face Shaping Mask  Face Shaping Mask'
#  'lyfcare Adult Pull-Up Pants Diapers| XL-20 Pieces|Waist Size :35-54 Inch|Pack of 2 - XL??????(20 Pieces)'
#  'Mylab CoviSelf COVID-19 Rapid COVID-19 Rapid Antigen Kit (Home-based/self)'
#  'DULCET DC-D9000X 220W Detachable Front Panel Universal Fit Single Din Mp3 Car Stereo with Dual USB Ports/Bluetooth/Hands Free Calling/FM/AUX Input/SD Card Slot & Remote Control DC-D9000X Car Stereo??????(Single Din)'
#  'Electronic Spices Tweeter 1.5-inch 240 Watts Max Dome Tweeters with Mounting Kit Angle, BLACK, Surface Set of 2 Tweeter Car Speaker??????(240 W)'
#  'DULCET DC-F200X 220W High Power Stereo Output Universal Fit Double Din Mp3 Car Stereo with Hands-Free Calling, Bluetooth, USB Input FM Radio, AUX Input, SD Card Slot, Remote Control, 7 Color LCD Display, ID3 Tag with EQ, Bass, Treble Balance & Fader Control DC-F200X Car Stereo??????(Double Din)'
#  'Vidisa Audio Interface AMP iRig System Guitar Effects Pedal Audio Reciver??????(Black)'
#  'FAVOURITE MALL Multimedia Ampli Tube Guitar Interface Adaptor for iPhone/iPod/ipad (Black colour) irig??????(Black colour)'
#  'FITUP ????? iPhone And Type C Supported K8 Wireless Microphone Lapel Mic System for YouTube Facebook Live Stream TikTok Video Recording Vlog Plug & Play Lavalier Noise Reduction No APP & Bluetooth Needed Collar Mic??????(Black)'
#  'gyzmofreakz 3.5mm Clip Microphone For Youtube | Collar Mike for Voice Recording | Lapel Mic Mobile, PC, Laptop, Android Smartphones, DSLR Camera Microphone microphone??????(Black)'
#  'SONY XM-N1004 Multi Class AB Car Amplifier'
#  'SONY XM-N502 Two Class AB Car Amplifier'
#  "godryft by GoMechanic Premium Speakers with Extra Bass & Superior Sound Technology S2 6'' 70W RMS 280W 2 Way Super Bass Series Coaxial Car Speaker Coaxial Car Speaker??????(280 W)"
#  'Cola Music Bamboo Flute??????(45 cm)'
#  'SONY Mega Bass Xs-Fb162e Coaxial Car Speaker??????(260 W)'
#  'Sound Boss Androidify 3rd Generation 9" Inch Android (2GB/16GB) Car Stereo??????(Double Din)'
#  'JXL 3way 6 inch Car Speaker 1690 Coaxial Car Speaker??????(600 W)'
#  'songbird 4 INCH 280 W MAX DOOR SPEAKER With Dual SB-B10-15S Coaxial Car Speaker??????(280 W)'
#  'Sound Boss SB-2032 BLUETOOTH/USB/SD/AUX/FM/MP3 Car Stereo??????(Single Din)'
#  'Shopfloor.XYZ 3.5mm Clip Microphone For Youtube, Collar Mike For Voice Recording, Lapel Mic Mobile, Pc, Laptop, Android Smartphones, Dslr Camera Clip On Mini Lapel Lavalier Microphone??????(Black)'
#  'mobspy 3.5mm Clip Microphone For Youtube | Collar Mic for Voice Recording | Lapel Mic Mobile, PC, Laptop, Android Smartphones, DSLR Camera Microphone Microphone collar mic??????(Black)'
#  'Bella vita organic OUD PARFUM Intense Perfume For Men & Women with Long Lasting Fragrance 100 ML Perfume  -  100 ml??????(For Men & Women)'
#  'Charlene Unisex Intimate Spray Mist Perfume (50ml, Pack of 1) Perfume  -  50 ml??????(For Men & Women)'
#  'Bella vita organic Luxury Unisex Perfume Gift Set For Men & Women- 4x20 ML Eau de Parfum  -  80 ml??????(For Men & Women)'
#  'ENVY Combo Perfume For Men 60ML + 60ML Eau de Parfum  -  120 ml??????(For Men)']

# %%
# Drop empty, NaN, or placeholder reviews
df = df[~df['Review'].isna()]                     # Remove NaNs
df = df[df['Review'].str.strip().str.lower() != 'not specified']  # Remove 'not specified'

# Optional: reset index
df.reset_index(drop=True, inplace=True)

# Check
print(df[['product_name', 'Review', 'flair_sentiment']].head())
print(f"Remaining reviews: {len(df)}")
# Out:
#                                         product_name           Review  \
# 0  Candes 12 L Room/Personal Air Cooler??????(Whi...           super!
# 1  Candes 12 L Room/Personal Air Cooler??????(Whi...          awesome
# 2  Candes 12 L Room/Personal Air Cooler??????(Whi...             fair
# 3  Candes 12 L Room/Personal Air Cooler??????(Whi...  useless product
# 4  Candes 12 L Room/Personal Air Cooler??????(Whi...             fair
#
#   flair_sentiment
# 0        positive
# 1        positive
# 2        negative
# 3        negative
# 4        negative
# Remaining reviews: 35877

# %%
# Normalize strings for safer matching
def normalize(text):
    if pd.isna(text):
        return ""
    text = text.lower()
    text = re.sub(r'[^a-z0-9\s]', ' ', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

# Precompute normalized product names
normalized_products = [normalize(p) for p in unique_products]

# %%
def products_by_phrase_or_token(keyword):
    """
    Return product names where the full phrase exists OR all tokens present.
    """
    k = normalize(keyword)
    if not k:
        return []

    # Phrase match
    phrase_matches = [prod for prod, nprod in zip(unique_products, normalized_products) if k in nprod]
    if phrase_matches:
        return phrase_matches

    #Token match
    tokens = k.split()
    token_matches = []
    for prod, nprod in zip(unique_products, normalized_products):
        if all(tok in nprod.split() for tok in tokens):
            token_matches.append(prod)
    return token_matches

# %%
# ------------------ Helper: Recommend similar products using flair ------------------
def recommend_similar_among_matches(selected_product, matched_products, keyword, top_n=3):
    """
    Recommend top products (excluding the selected one) among matched products
    based on positive flair sentiment.
    """
    # Exclude the selected product
    other_products = [p for p in matched_products if p != selected_product]

    if not other_products:
        print("No other products to recommend.")
        return

    # Filter only other products whose name contains the keyword
    mask_products = df['product_name'].isin(other_products)
    df_filtered = df[mask_products]

    # Filter only positive flair sentiment reviews
    df_positive = df_filtered[df_filtered['flair_sentiment'] == 'positive']

    if df_positive.empty:
        print("No positive reviews found among other matched products.")
        return

    # Count positive reviews per product
    positive_counts = df_positive.groupby('product_name').size().sort_values(ascending=False)

    # Take top N
    top_recommendations = positive_counts.head(top_n)

    print(f"\n--- Top {top_n} similar products based on positive Flair reviews ---")
    for idx, (prod, count) in enumerate(top_recommendations.items(), 1):
        print(f"{idx}. {prod} → Positive Reviews: {count}")

# %%
# ------------------ Main search function using only Flair sentiment ------------------
def search_reviews_by_sentiment_flair(threshold=70, max_fuzzy_matches=10):
    # Ask keyword and remember it
    keyword = input("Enter product name or keyword to search: ").strip()
    if not keyword:
        print("Empty keyword. Exiting.")
        return

    # Phrase/token matching
    matched_products = products_by_phrase_or_token(keyword)

    # Fuzzy fallback if no matches
    if not matched_products:
        print("No exact/phrase/token matches found — using fuzzy fallback.")
        fuzzy_results = []
        for prod, nprod in zip(unique_products, normalized_products):
            score = fuzz.token_set_ratio(normalize(keyword), nprod)
            fuzzy_results.append((prod, score))
        fuzzy_results = sorted(fuzzy_results, key=lambda x: x[1], reverse=True)
        fuzzy_matches = [prod for prod, score in fuzzy_results if score >= threshold]
        matched_products = fuzzy_matches[:max_fuzzy_matches]

    if not matched_products:
        print(f"No products found for keyword '{keyword}' (even after fuzzy).")
        return

    # Show matches
    print(f"\nFound {len(matched_products)} matches for '{keyword}':")
    for idx, p in enumerate(matched_products, 1):
        print(f"{idx}. {p}")

    # Let user select product(s)
    while True:
        choice = input("\nEnter the number of the product to see reviews, or 'all' to see all: ").strip().lower()
        if choice == "all":
            selected_products = matched_products
            break
        elif choice.isdigit() and 1 <= int(choice) <= len(matched_products):
            selected_products = [matched_products[int(choice)-1]]
            break
        else:
            print("Invalid input! Enter a valid number or 'all'.")

    # Filter reviews
    matched_norms = [normalize(p) for p in selected_products]
    mask_prod = df['product_name'].fillna('').apply(lambda x: normalize(x) in matched_norms)
    mask_review = df['Review'].fillna('').str.contains(keyword, case=False, na=False)
    filtered = df[mask_prod | mask_review].copy()
    if filtered.empty:
        print("No reviews found for selected products.")
        return

    # Sentiment filter (only Flair sentiment)
    chosen_sentiment = input("Enter sentiment (positive/negative/neutral/all): ").strip().lower()
    if chosen_sentiment != 'all':
        filtered = filtered[filtered['flair_sentiment'].str.lower() == chosen_sentiment]
        if filtered.empty:
            print(f"No reviews found with sentiment '{chosen_sentiment}'.")
            return

    # Display reviews
    print(f"\n--- Reviews for selected products (Flair sentiment = '{chosen_sentiment}') ---\n")
    for prod in selected_products:
        sub = filtered[filtered['product_name'].str.lower() == prod.lower()]
        if sub.empty:
            continue
        print(f"Product: {prod}   ({len(sub)} reviews)\n" + "-"*60)
        for i, row in enumerate(sub.itertuples(), 1):
            print(f"{i}. ({row.flair_sentiment}) {row.Review}")
        print("\n")

    # Show other reviews that matched keyword in review text
    other = filtered[~filtered['product_name'].str.lower().isin([p.lower() for p in selected_products])]
    if not other.empty:
        print("Other reviews matched by keyword in review text:\n" + "-"*60)
        for i, row in enumerate(other.itertuples(), 1):
            print(f"{i}. ({row.flair_sentiment}) [{row.product_name}] {row.Review}")
        print("\n")

    # Sentiment stats
    stats = filtered['flair_sentiment'].value_counts(normalize=True) * 100
    print("\n--- Combined Flair Sentiment Stats (% of matched reviews) ---")
    print(stats.round(2))

    # Recommend top products among other matched products
    recommend_similar_among_matches(selected_products[0], matched_products, keyword=keyword, top_n=3)

# %%
search_reviews_by_sentiment_flair()
# Out:
# Enter product name or keyword to search: cooler
#
# Found 4 matches for 'cooler':
# 1. Candes 12 L Room/Personal Air Cooler??????(White, Black, Elegant High Speed-Honey Comb Cooling Pad & Ice Chamber, Blower)
# 2. Candes 60 L Room/Personal Air Cooler??????(White, Black, CRETA)
# 3. MAHARAJA WHITELINE 65 L Desert Air Cooler??????(White, Grey, Rambo Grey / AC-303)
# 4. Crompton 75 L Desert Air Cooler??????(White, Teal, ACGC-DAC751)
#
# Enter the number of the product to see reviews, or 'all' to see all: 1
# Enter sentiment (positive/negative/neutral/all): all
#
# --- Reviews for selected products (Flair sentiment = 'all') ---
#
# Product: Candes 12 L Room/Personal Air Cooler??????(White, Black, Elegant High Speed-Honey Comb Cooling Pad & Ice Chamber, Blower)   (10 reviews)
# ------------------------------------------------------------
# 1. (positive) super!
# 2. (positive) awesome
# 3. (negative) fair
# 4. (negative) useless product
# 5. (negative) fair
# 6. (positive) awesome
# 7. (positive) highly recommended
# 8. (positive) nice
# 9. (negative) unsatisfactory
# 10. (positive) worth the money
#
#
# Other reviews matched by keyword in review text:
# ------------------------------------------------------------
# 1. (positive) [MAHARAJA WHITELINE 65 L Desert Air Cooler??????(White, Grey, Rambo Grey / AC-303)] good cooler
# 2. (positive) [Crompton 75 L Desert Air Cooler??????(White, Teal, ACGC-DAC751)] worth the money . desert cooler live up to the name .
# 3. (negative) [Crompton 75 L Desert Air Cooler??????(White, Teal, ACGC-DAC751)] its not a cooler its ac cooler
# 4. (negative) [Crompton 75 L Desert Air Cooler??????(White, Teal, ACGC-DAC751)] ok kind of cooler..not effective in hot conditions
# 5. (positive) [Crompton 75 L Desert Air Cooler??????(White, Teal, ACGC-DAC751)] awesome cooler
# 6. (positive) [Crompton 75 L Desert Air Cooler??????(White, Teal, ACGC-DAC751)] cool cooler for extreme summer heat
# 7. (positive) [Crompton 75 L Desert Air Cooler??????(White, Teal, ACGC-DAC751)] best cooler !
# 8. (positive) [Crompton 75 L Desert Air Cooler??????(White, Teal, ACGC-DAC751)] fantastic air cooler in affordable price
# 9. (positive) [Crompton 75 L Desert Air Cooler??????(White, Teal, ACGC-DAC751)] ultimate cooler at this price range
# 10. (positive) [Crompton 75 L Desert Air Cooler??????(White, Teal, ACGC-DAC751)] fab cooler
# 11. (positive) [Crompton 75 L Desert Air Cooler??????(White, Teal, ACGC-DAC751)] crompton ozone 75 desert air cooler
#
#
#
# --- Combined Flair Sentiment Stats (% of matched reviews) ---
# flair_sentiment
# positive    71.43
# negative    28.57
# Name: proportion, dtype: float64
#
# --- Top 3 similar products based on positive Flair reviews ---
# 1. Crompton 75 L Desert Air Cooler??????(White, Teal, ACGC-DAC751) → Positive Reviews: 980
# 2. MAHARAJA WHITELINE 65 L Desert Air Cooler??????(White, Grey, Rambo Grey / AC-303) → Positive Reviews: 663
# 3. Candes 60 L Room/Personal Air Cooler??????(White, Black, CRETA) → Positive Reviews: 25
